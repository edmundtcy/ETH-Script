# %% [markdown]
# ### Just a script to analyse my hyperliquid airdrop farm

# %%
import os
import pandas as pd
import numpy as np

# %%
file_path = r"C:\Users\Love\Downloads\trade_history.csv"
df = pd.read_csv(file_path)
os.remove(file_path)
df['time'] = pd.to_datetime(df['time'])
df['type'] = df.apply(lambda row: 'maker' if row['fee'] / row['ntl'] <= 0.0001 else 'taker', axis=1)
df.tail(30)
# Out:
#                     time    coin         dir        px        sz          ntl  \
# 1765 2024-04-24 01:27:22  kFLOKI   Open Long  0.201560    2283.0   460.161480
# 1766 2024-04-24 01:27:22  kFLOKI   Open Long  0.201560    1608.0   324.108480
# 1767 2024-04-24 01:30:19  kFLOKI  Close Long  0.201090    3463.0   696.374670
# 1768 2024-04-24 01:30:19  kFLOKI  Close Long  0.201080    2711.0   545.127880
# 1769 2024-04-24 01:36:31   kBONK   Open Long  0.022749   10692.0   243.232308
# 1770 2024-04-24 01:38:37   kBONK  Close Long  0.022613   10692.0   241.778196
# 1771 2024-04-24 01:40:48   kPEPE   Open Long  0.007751  294221.0  2280.506971
# 1772 2024-04-24 01:41:33   kPEPE  Close Long  0.007753  290210.0  2249.998130
# 1773 2024-04-24 01:41:33   kPEPE  Close Long  0.007753    4011.0    31.097283
# 1774 2024-04-24 01:46:05   kBONK   Open Long  0.022739   65369.0  1486.425691
# 1775 2024-04-24 02:02:16   kBONK  Close Long  0.022600   65369.0  1477.339400
# 1776 2024-04-24 02:03:32   kPEPE   Open Long  0.007722  100000.0   772.200000
# 1777 2024-04-24 02:03:32   kPEPE   Open Long  0.007722  201216.0  1553.789952
# 1778 2024-04-24 02:12:56   kPEPE  Close Long  0.007655  139711.0  1069.487705
# 1779 2024-04-24 02:12:56   kPEPE  Close Long  0.007655  127553.0   976.418215
# 1780 2024-04-24 02:12:56   kPEPE  Close Long  0.007654   33952.0   259.868608
# 1781 2024-04-24 02:16:29   kPEPE   Open Long  0.007707  100000.0   770.700000
# 1782 2024-04-24 02:16:30   kPEPE   Open Long  0.007707   58997.0   454.689879
# 1783 2024-04-24 02:16:32   kPEPE   Open Long  0.007707  115948.0   893.611236
# 1784 2024-04-24 02:23:08   kPEPE  Close Long  0.007744    1596.0    12.359424
# 1785 2024-04-24 02:23:08   kPEPE  Close Long  0.007744  273349.0  2116.814656
# 1786 2024-04-24 02:25:38   kPEPE   Open Long  0.007750   22573.0   174.940750
# 1787 2024-04-24 02:25:41   kPEPE   Open Long  0.007750   20145.0   156.123750
# 1788 2024-04-24 02:25:41   kPEPE   Open Long  0.007750  100000.0   775.000000
# 1789 2024-04-24 02:25:41   kPEPE   Open Long  0.007750  141998.0  1100.484500
# 1790 2024-04-24 02:27:18   kPEPE  Close Long  0.007751  100000.0   775.100000
# 1791 2024-04-24 02:27:18   kPEPE  Close Long  0.007751  184716.0  1431.733716
# 1792 2024-04-24 02:46:07   kPEPE   Open Long  0.007725   58997.0   455.751825
# 1793 2024-04-24 02:46:07   kPEPE   Open Long  0.007725  221049.0  1707.603525
# 1794 2024-04-24 02:46:54   kPEPE  Close Long  0.007743  280046.0  2168.396178
#
#            fee  closedPnl   type
# 1765  0.044175  -0.044175  maker
# 1766  0.031113  -0.031113  maker
# 1767  0.233981  -1.861591  taker
# 1768  0.183162  -1.484442  taker
# 1769  0.081725  -0.081725  taker
# 1770  0.081237  -1.535349  taker
# 1771  0.218928  -0.218928  maker
# 1772  0.755999  -0.175579  taker
# 1773  0.010448  -0.002426  taker
# 1774  0.499438  -0.499438  taker
# 1775  0.496385  -9.582676  taker
# 1776  0.074131  -0.074131  maker
# 1777  0.149162  -0.149162  maker
# 1778  0.359347  -9.719984  taker
# 1779  0.328076  -8.874127  taker
# 1780  0.087315  -2.396051  taker
# 1781  0.073987  -0.073987  maker
# 1782  0.043649  -0.043649  maker
# 1783  0.085786  -0.085786  maker
# 1784  0.004152   0.054900  taker
# 1785  0.711249   9.402664  taker
# 1786  0.016794  -0.016794  maker
# 1787  0.014987  -0.014987  maker
# 1788  0.074400  -0.074400  maker
# 1789  0.105646  -0.105646  maker
# 1790  0.260433  -0.160433  taker
# 1791  0.481061  -0.296345  taker
# 1792  0.043752  -0.043752  maker
# 1793  0.163929  -0.163929  maker
# 1794  0.208165   4.832663  maker

# %% [markdown]
# ### Historical Data

# %%
class position:
    def __init__(self, time, dir, coin, sz, ntl):
        self.time = time
        self.dir = dir
        self.coin = coin
        self.sz = sz
        self.ntl = ntl
    def reduce_size(self, sz, ntl):
        self.sz = self.sz - sz
        self.ntl = self.ntl + ntl
    def increase_size(self, sz, ntl):
        self.sz = self.sz + sz
        self.ntl = self.ntl + ntl

open_position_value = []
closed_trade = []

for index, row in df.iterrows():
    if row['dir'] == 'Open Long' or row['dir'] == 'Open Short' or row['dir'] == 'Long > Short' or row['dir'] == 'Short > Long':
        found = False
        for trade in open_position_value:
            if trade.coin == row['coin'] and trade.dir == row['dir']:
                trade.increase_size(row['sz'], row['ntl'])
                found = True
                break
        if not found:
            open_position_value.append(position(row['time'], row['dir'], row['coin'], row['sz'], row['ntl']))

    elif row['dir'] == 'Close Long' or row['dir'] == 'Market Order Liquidation: Close Long':
        for trade in open_position_value:
            if trade.coin == row['coin'] and trade.dir == 'Open Long':
                trade.reduce_size(row['sz'], row['ntl'])
                if trade.sz < 0.1:
                    closed_trade.append([trade.time, trade.coin, row['time']-trade.time, trade.ntl])
                    open_position_value.remove(trade)
    
    elif row['dir'] == 'Close Short' or row['dir'] == 'Market Order Liquidation: Close Short':
        for trade in open_position_value:
            if trade.coin == row['coin'] and trade.dir == 'Open Short':
                trade.reduce_size(row['sz'], row['ntl'])
                if trade.sz < 0.1:
                    closed_trade.append([trade.time, trade.coin, row['time']-trade.time, trade.ntl])
                    open_position_value.remove(trade)

result = [{'time': row[0], 'coin': row[1], 'duration': row[2], 'ntl': row[3]} for row in closed_trade]
df_duration = pd.DataFrame(result)
df_duration
# Out:
#                    time    coin        duration          ntl
# 0   2024-02-13 17:46:05     BTC 0 days 01:03:17  3990.987000
# 1   2024-02-13 19:01:27     ETH 0 days 02:30:25  3993.621750
# 2   2024-02-13 21:38:25     ETH 0 days 18:05:18  4218.086520
# 3   2024-02-14 15:50:28     ETH 0 days 01:16:53  4455.093050
# 4   2024-02-14 17:10:22     BTC 0 days 01:56:59  2401.850920
# ..                  ...     ...             ...          ...
# 251 2024-04-24 01:23:03   kBONK 0 days 00:02:05  4804.127745
# 252 2024-04-24 01:25:25   kBONK 0 days 00:01:14  4872.497268
# 253 2024-04-24 01:27:22  kFLOKI 0 days 00:02:57  2485.933990
# 254 2024-04-24 01:36:31   kBONK 0 days 00:02:06   485.010504
# 255 2024-04-24 01:46:05   kBONK 0 days 00:16:11  2963.765091
#
# [256 rows x 4 columns]

# %%
df
# Out:
#                     time   coin         dir            px            sz  \
# 0    2024-02-13 17:46:05    BTC   Open Long  50161.000000       0.03987
# 1    2024-02-13 18:49:22    BTC  Close Long  49939.000000       0.03987
# 2    2024-02-13 19:01:27    ETH   Open Long   2670.700000       0.74850
# 3    2024-02-13 21:31:52    ETH  Close Long   2664.800000       0.74850
# 4    2024-02-13 21:38:25    ETH   Open Long   2634.100000       0.79740
# ...                  ...    ...         ...           ...           ...
# 1790 2024-04-24 02:27:18  kPEPE  Close Long      0.007751  100000.00000
# 1791 2024-04-24 02:27:18  kPEPE  Close Long      0.007751  184716.00000
# 1792 2024-04-24 02:46:07  kPEPE   Open Long      0.007725   58997.00000
# 1793 2024-04-24 02:46:07  kPEPE   Open Long      0.007725  221049.00000
# 1794 2024-04-24 02:46:54  kPEPE  Close Long      0.007743  280046.00000
#
#               ntl       fee  closedPnl   type
# 0     1999.919070  0.479979  -0.479979  taker
# 1     1991.067930  0.477855  -9.328995  taker
# 2     1999.018950  0.479763  -0.479763  taker
# 3     1994.602800  0.478704  -4.894854  taker
# 4     2100.431340  0.504102  -0.504102  taker
# ...           ...       ...        ...    ...
# 1790   775.100000  0.260433  -0.160433  taker
# 1791  1431.733716  0.481061  -0.296345  taker
# 1792   455.751825  0.043752  -0.043752  maker
# 1793  1707.603525  0.163929  -0.163929  maker
# 1794  2168.396178  0.208165   4.832663  maker
#
# [1795 rows x 9 columns]

# %% [markdown]
# ### To see which pair I should farm

# %%
start = [
    pd.Timestamp('2024-04-17 08:00:00'),
    pd.Timestamp('2024-04-10 08:00:00'),
    pd.Timestamp('2024-04-03 08:00:00'),
    pd.Timestamp('2024-03-06 08:00:00'),
    pd.Timestamp('2024-02-28 08:00:00'),
    pd.Timestamp('2024-02-21 08:00:00'),
    pd.Timestamp('2024-02-14 08:00:00'),
    pd.Timestamp('2024-02-07 08:00:00')
]
end = [
    pd.Timestamp('2024-04-24 08:00:00'),
    pd.Timestamp('2024-04-17 08:00:00'),
    pd.Timestamp('2024-04-10 08:00:00'),
    pd.Timestamp('2024-03-13 08:00:00'),
    pd.Timestamp('2024-03-06 08:00:00'),
    pd.Timestamp('2024-02-28 08:00:00'),
    pd.Timestamp('2024-02-21 08:00:00'),
    pd.Timestamp('2024-02-14 08:00:00')
]
total_exchange_volume = [
    1,
    13748000000,
    9673806247,
    10823100000,
    15440000000,
    8650700000,
    7601300000,
    7573400000
]
points = [1,73,168,82,25,9,7,1]
total_volume = []
for i in range(len(start)):
    start_time = start[i]
    end_time = end[i]
    filtered_df = df[(df['time'] >= start_time) & (df['time'] < end_time)]
    volume = filtered_df['ntl'].sum()
    total_volume.append(volume)
    taker_total_ntl = filtered_df.loc[filtered_df['type'] == 'taker', 'ntl'].sum()
    maker_total_ntl = filtered_df.loc[filtered_df['type'] == 'maker', 'ntl'].sum()
    taker_percentage = round((taker_total_ntl / volume) * 100, 2)
    maker_percentage = round((maker_total_ntl / volume) * 100, 2)
    filtered_df = df_duration[(df_duration['time'] >= start_time) & (df_duration['time'] < end_time)]
    coin_volume = filtered_df.groupby('coin')['ntl'].sum().sort_values(ascending=False)
    average_duration = np.mean([duration.total_seconds() for duration in filtered_df['duration']])
    print(f"Time period: {start_time} - {end_time}")
    print("Coin\t\tVolume")
    for coin, volume in coin_volume.items():
        print(f"{coin}\t\t{volume}")
    print(f"Average duration: {average_duration} seconds")
    print(f"Points: {points[i]}")
    print(f"My volume: {total_volume[i]}")
    print("Taker Percentage:", taker_percentage, "%")
    print("Maker Percentage:", maker_percentage, "%")
    print(f"Exchange volume: {total_exchange_volume[i]}")
    print(f"My volume share: {total_volume[i]/total_exchange_volume[i] * 100}%")
    print(f"My theoretical points: {total_volume[i]/total_exchange_volume[i] * 1000000}")
    print(f"Volume per point: {total_volume[i]/points[i]}")
    print("-----------------------------------------------------------------------------")
# Out:
# Time period: 2024-04-17 08:00:00 - 2024-04-24 08:00:00
# Coin		Volume
# kPEPE		221230.862783
# kBONK		38618.341803
# ETH		19785.0654
# kFLOKI		7488.71724
# MYRO		2211.53115
# Average duration: 1241.75 seconds
# Points: 1
# My volume: 501405.47153100005
# Taker Percentage: 71.29 %
# Maker Percentage: 28.71 %
# Exchange volume: 1
# My volume share: 50140547.15310001%
# My theoretical points: 501405471531.00006
# Volume per point: 501405.47153100005
# -----------------------------------------------------------------------------
# Time period: 2024-04-10 08:00:00 - 2024-04-17 08:00:00
# Coin		Volume
# kPEPE		355829.140828
# ETH		287353.81153
# WIF		102795.6814
# BTC		65190.77239
# SOL		24492.880899999996
# DOGE		19577.80445
# TON		12878.65258
# W		3241.547515
# MYRO		1076.09778
# Average duration: 4211.958904109589 seconds
# Points: 73
# My volume: 979561.136438
# Taker Percentage: 39.37 %
# Maker Percentage: 60.63 %
# Exchange volume: 13748000000
# My volume share: 0.007125117372985162%
# My theoretical points: 71.25117372985162
# Volume per point: 13418.645704630137
# -----------------------------------------------------------------------------
# Time period: 2024-04-03 08:00:00 - 2024-04-10 08:00:00
# Coin		Volume
# ETH		707213.0103600001
# BTC		513833.46206
# kPEPE		702.5579
# WIF		515.394
# Average duration: 9220.55223880597 seconds
# Points: 168
# My volume: 1273599.58267
# Taker Percentage: 56.31 %
# Maker Percentage: 43.69 %
# Exchange volume: 9673806247
# My volume share: 0.01316544439852683%
# My theoretical points: 131.6544439852683
# Volume per point: 7580.949896845237
# -----------------------------------------------------------------------------
# Time period: 2024-03-06 08:00:00 - 2024-03-13 08:00:00
# Coin		Volume
# kPEPE		105242.25604
# MYRO		9896.55031
# BTC		1046.1448799999998
# Average duration: 14051.833333333334 seconds
# Points: 82
# My volume: 116184.95123
# Taker Percentage: 55.84 %
# Maker Percentage: 44.16 %
# Exchange volume: 10823100000
# My volume share: 0.001073490508541915%
# My theoretical points: 10.73490508541915
# Volume per point: 1416.8896491463415
# -----------------------------------------------------------------------------
# Time period: 2024-02-28 08:00:00 - 2024-03-06 08:00:00
# Coin		Volume
# SOL		123071.4031
# Average duration: 518.0 seconds
# Points: 25
# My volume: 123071.40310000001
# Taker Percentage: 90.4 %
# Maker Percentage: 9.6 %
# Exchange volume: 15440000000
# My volume share: 0.0007970945796632125%
# My theoretical points: 7.970945796632125
# Volume per point: 4922.856124000001
# -----------------------------------------------------------------------------
# Time period: 2024-02-21 08:00:00 - 2024-02-28 08:00:00
# Coin		Volume
# ETH		189579.39609
# Average duration: 6827.28 seconds
# Points: 9
# My volume: 190606.93544000003
# Taker Percentage: 100.0 %
# Maker Percentage: 0.0 %
# Exchange volume: 8650700000
# My volume share: 0.0022033700791843436%
# My theoretical points: 22.033700791843437
# Volume per point: 21178.548382222227
# -----------------------------------------------------------------------------
# Time period: 2024-02-14 08:00:00 - 2024-02-21 08:00:00
# Coin		Volume
# ETH		34579.59835
# BTC		14631.41089
# DYM		7625.89685
# PYTH		2502.87822
# BLUR		499.00268
# Average duration: 35676.318181818184 seconds
# Points: 7
# My volume: 63076.6586
# Taker Percentage: 100.0 %
# Maker Percentage: 0.0 %
# Exchange volume: 7601300000
# My volume share: 0.0008298140923263126%
# My theoretical points: 8.298140923263126
# Volume per point: 9010.951228571428
# -----------------------------------------------------------------------------
# Time period: 2024-02-07 08:00:00 - 2024-02-14 08:00:00
# Coin		Volume
# ETH		8211.708270000001
# BTC		3990.987
# Average duration: 25980.0 seconds
# Points: 1
# My volume: 10085.04009
# Taker Percentage: 100.0 %
# Maker Percentage: 0.0 %
# Exchange volume: 7573400000
# My volume share: 0.00013316396981540656%
# My theoretical points: 1.3316396981540657
# Volume per point: 10085.04009
# -----------------------------------------------------------------------------

# %% [markdown]
# ### Progress

# %%
daily_ntl_sum = df.groupby(pd.Grouper(key='time', freq='D'))['ntl'].sum()
print(daily_ntl_sum.tail(21))
print("Rolling 14 days  volume: ",daily_ntl_sum.tail(14).sum())
total_volume = df['ntl'].sum()
print("Total volume: ", total_volume)
# Out:
# time
# 2024-04-04         0.000000
# 2024-04-05    196199.775858
# 2024-04-06     33894.245520
# 2024-04-07    206996.333780
# 2024-04-08    320720.368140
# 2024-04-09    361976.122952
# 2024-04-10    361706.154720
# 2024-04-11     99332.876844
# 2024-04-12    120356.720167
# 2024-04-13    117499.056678
# 2024-04-14     97661.356584
# 2024-04-15    142299.499972
# 2024-04-16    174897.791693
# 2024-04-17    219994.915538
# 2024-04-18    119471.511425
# 2024-04-19     41338.689377
# 2024-04-20      6043.250902
# 2024-04-21      1899.116814
# 2024-04-22      2249.958380
# 2024-04-23     24893.568990
# 2024-04-24    105134.876305
# Freq: D, Name: ntl, dtype: float64
# Rolling 14 days  volume:  1273073.1896690002
# Total volume:  3257591.179099

# %%
daily_closedPnl_sum = df.groupby(pd.Grouper(key='time', freq='D'))['closedPnl'].sum()
print(daily_closedPnl_sum.tail(14))
print("7 days total PnL: ",daily_closedPnl_sum.tail(14).sum())

# %% [markdown]
# ### Position size calculator

# %%
leverage_x = 10
leverage_y = 20
capital = 5870.33
x = leverage_y/leverage_x #y
y_allocation = capital/(1+x)
x_allocation = capital - y_allocation
print(x_allocation, y_allocation)
# Out:
# 3913.5533333333333 1956.7766666666666
